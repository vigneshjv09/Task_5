# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshjv09/Task_5/blob/main/Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from datetime import datetime

# %%
df=pd.read_csv("/content/takehome_user_engagement.csv")
df
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30      1.0      1.0
# 1       2013-11-15 03:45:04      2.0      1.0
# 2       2013-11-29 03:45:04      2.0      1.0
# 3       2013-12-09 03:45:04      2.0      1.0
# 4       2013-12-25 03:45:04      2.0      1.0
# ...                     ...      ...      ...
# 150465  2013-04-15 20:39:46   8679.0      1.0
# 150466  2013-04-20 20:39:46   8679.0      1.0
# 150467  2013-04-24 20:39:46   8679.0      1.0
# 150468  2013-04-29 20:39:46   8679.0      1.0
# 150469   2013-04-30 20:39:4      NaN      NaN
#
# [150470 rows x 3 columns]

# %% [markdown]
# $\color{red}{\text{**Checking for adopted user(who has logged into the product on three separate days in at least one seven­ day period**)}}$

# %% [markdown]
# $\color{blue}{\text{Changing time_stamp in dataframe to pandas datetime format}}$

# %%
df['time_stamp']=pd.to_datetime(df['time_stamp'])

# %% [markdown]
# $\color{blue}{\text{Grouping Users as per weekly window and finding the visit count as per weekly time frame}}$

# %%
g= df.groupby('user_id')
date=g.rolling('7D', on='time_stamp')['visited'].count()
date=date.to_frame().reset_index()

# %%
date
# Out:
#         user_id          time_stamp  visited
# 0           1.0 2014-04-22 03:53:30      1.0
# 1           2.0 2013-11-15 03:45:04      1.0
# 2           2.0 2013-11-29 03:45:04      1.0
# 3           2.0 2013-12-09 03:45:04      1.0
# 4           2.0 2013-12-25 03:45:04      1.0
# ...         ...                 ...      ...
# 150464   8679.0 2013-04-08 20:39:46      1.0
# 150465   8679.0 2013-04-15 20:39:46      1.0
# 150466   8679.0 2013-04-20 20:39:46      2.0
# 150467   8679.0 2013-04-24 20:39:46      2.0
# 150468   8679.0 2013-04-29 20:39:46      2.0
#
# [150469 rows x 3 columns]

# %% [markdown]
# $\color{blue}{\text{Finding adopted users who has logged into the product on three separate days in at least one seven­ day period}}$

# %%
def adp_user(adopted):
  adopted=adopted.groupby('user_id')['visited'].max().reset_index()
  adopted_user=adopted
  adopted_user['adopted_user']=adopted['visited'].apply(lambda x: 1 if x>=3 else 0)
  return adopted_user
adopted_user=adp_user(date)

# %%
adopted_user
# Out:
#       user_id  visited  adopted_user
# 0         1.0      1.0             0
# 1         2.0      3.0             1
# 2         3.0      1.0             0
# 3         4.0      1.0             0
# 4         5.0      1.0             0
# ...       ...      ...           ...
# 6344   8675.0      4.0             1
# 6345   8676.0      1.0             0
# 6346   8677.0      3.0             1
# 6347   8678.0      1.0             0
# 6348   8679.0      4.0             1
#
# [6349 rows x 3 columns]

# %%
adopted_user.adopted_user.value_counts()
# Out:
# 0    5206
# 1    1143
# Name: adopted_user, dtype: int64

# %%
adopted_user.drop('visited',axis=1,inplace=True)
adopted_user.rename({'user_id':'object_id'},axis=1,inplace=True)
adopted_user.set_index("object_id", inplace = True)

# %% [markdown]
# $\color{red}{\text{**Reading the takehome_user file and merging the adopted uder dataframe with it**}}$

# %%
df1=pd.read_csv("/content/takehome_users.csv",encoding='latin-1')
df1
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# 4              GraceRaw@yahoo.com        GUEST_INVITE
# ...                           ...                 ...
# 11995       SophiaMeier@gustr.com          ORG_INVITE
# 11996      AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 11997         JakeHaynes@cuvox.de        GUEST_INVITE
# 11998          mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 11999   ThaisMeloLima@hotmail.com              SIGNUP
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0                    1.398139e+09                         1
# 1                    1.396238e+09                         0
# 2                    1.363735e+09                         0
# 3                    1.369210e+09                         0
# 4                    1.358850e+09                         0
# ...                           ...                       ...
# 11995                1.378448e+09                         0
# 11996                1.358275e+09                         0
# 11997                1.398603e+09                         1
# 11998                1.338638e+09                         0
# 11999                1.390727e+09                         0
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# 0                               0      11             10803.0
# 1                               0       1               316.0
# 2                               0      94              1525.0
# 3                               0       1              5151.0
# 4                               0     193              5240.0
# ...                           ...     ...                 ...
# 11995                           0      89              8263.0
# 11996                           0     200                 NaN
# 11997                           1      83              8074.0
# 11998                           0       6                 NaN
# 11999                           1       0                 NaN
#
# [12000 rows x 10 columns]

# %%
user=df1.join(adopted_user,how='left',on='object_id')
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
#  10  adopted_user                6349 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 1.0+ MB

# %%
user.fillna(0,inplace=True)

# %% [markdown]
# $\color{red}{\text{**DATA CLEANING**}}$

# %%
user['last_session_creation_time'] =  user['last_session_creation_time'].apply(lambda d: datetime.fromtimestamp(int(d)).strftime('%Y-%m-%d %H:%M:%S'))
user['last_session_creation_time'] = pd.to_datetime(user['last_session_creation_time'])

# %%
user.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com      ORG_INVITE        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com      ORG_INVITE        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com    GUEST_INVITE        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id  adopted_user
# 0             10803.0           0.0
# 1               316.0           1.0
# 2              1525.0           0.0
# 3              5151.0           0.0
# 4              5240.0           0.0

# %%
user['creation_time'] = user['creation_time'].apply(lambda x: datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S'))
user['creation_time'] = pd.to_datetime(user['creation_time'])
user.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com      ORG_INVITE        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com      ORG_INVITE        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com    GUEST_INVITE        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id  adopted_user
# 0             10803.0           0.0
# 1               316.0           1.0
# 2              1525.0           0.0
# 3              5151.0           0.0
# 4              5240.0           0.0

# %%
src=list(user['creation_source'].unique())
for i in range(len(src)):  
    user['creation_source']=user['creation_source'].replace({src[i]:i})

# %%
user.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email  creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com                0        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com                1        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com                1        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com                0        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com                0        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id  adopted_user
# 0             10803.0           0.0
# 1               316.0           1.0
# 2              1525.0           0.0
# 3              5151.0           0.0
# 4              5240.0           0.0

# %% [markdown]
# $\color{blue}{\text{finding active days}}$

# %%
user['active_days']=(user['last_session_creation_time'].sub(user['creation_time'])).dt.days
col =user.pop('active_days')
user.insert(9,'active_days', col)
for i in range(len(user['active_days'])):
   if user['active_days'][i]<0:
      user['active_days'][i]=0
user.head()
# Out:
# <ipython-input-18-16b587a6667c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user['active_days'][i]=0
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email  creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com                0        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com                1        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com                1        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com                0        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com                0        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  active_days  \
# 0                         1                           0      11            0
# 1                         0                           0       1          136
# 2                         0                           0      94            0
# 3                         0                           0       1            1
# 4                         0                           0     193            5
#
#    invited_by_user_id  adopted_user
# 0             10803.0           0.0
# 1               316.0           1.0
# 2              1525.0           0.0
# 3              5151.0           0.0
# 4              5240.0           0.0

# %% [markdown]
# $\color{blue}{\text{Finding correlation between all columns with the adopted_user}}$

# %%
user.corr()['adopted_user']
# Out:
# object_id                    -0.156200
# creation_source              -0.021350
# opted_in_to_mailing_list      0.012347
# enabled_for_marketing_drip    0.007417
# org_id                        0.054604
# active_days                   0.670218
# invited_by_user_id            0.010522
# adopted_user                  1.000000
# Name: adopted_user, dtype: float64

# %% [markdown]
# $\color{blue}{\text{its seen from above that following column has more correlation to adopted_user}}$
#
# $\color{blue}{\text{1)org_id}}$
#
# $\color{blue}{\text{2)invited_by_user_id}}$
#
# $\color{blue}{\text{3)opted_in_to_mailing_list}}$
#
# $\color{blue}{\text{4)enabled_for_marketing_drip}}$
#
# $\color{blue}{\text{5)active_days  }}$

# %% [markdown]
# $\color{red}{\text{**Exploratory Data Analysis**}}$

# %%
sns.pairplot(user, hue="adopted_user",height=5)
plt.show()

# %% [markdown]
# $\color{blue}{\text{From the above plot we can conclude}}$$\color{blue}{\text{ org_id,
# invited_by_user_id,opting to mail list,enable for marketing drip,
# active_days and creation source}}$$\color{blue}{\text{are the features which can separate
# the data very well.}}$

# %%
figure=plt.figure(figsize=(10,10))
sns.scatterplot(user['active_days'],user['object_id'],user['adopted_user'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig=plt.figure(figsize=(10,10))
plt.hist(user.active_days[user['adopted_user']==1],color='blue')
plt.hist(user.active_days[user['adopted_user']==0],color='red')
plt.xlabel("active_days")
plt.ylabel("frequency")
plt.ylim(0,2000)
plt.show()

# %% [markdown]
#  <font color='blue'>
# </font>

# %% [markdown]
# $\color{blue}{\text{object_id with more active time are mostly adopted users and more active days has more adopted users}}$

# %%
arr=list(df1.creation_source.unique())
ind = np.arange(len(arr))

# %%
fig=plt.figure(figsize=(10,10))
sns.countplot(x='creation_source', data=user,hue='adopted_user', palette='Set2')
plt.xticks(ind,labels=arr,rotation=60)
plt.show()

# %% [markdown]
# $\color{blue}{\text{Creation source doesn't have much impact on adopted user}}$

# %% [markdown]
# $\color{red}{\text{***Let us try logistic regression and find important features***}}$

# %%
import statsmodels.api as sm

# %%
x=user[['creation_source','opted_in_to_mailing_list','enabled_for_marketing_drip','org_id','active_days','invited_by_user_id']]
y=user['adopted_user']

# %%
x_cons=sm.add_constant(x)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x_log=sm.Logit(y,x_cons)
res_log=x_log.fit()
res_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.185210
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           adopted_user   No. Observations:                12000
# Model:                          Logit   Df Residuals:                    11993
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 27 Feb 2023   Pseudo R-squ.:                  0.4111
# Time:                        20:36:42   Log-Likelihood:                -2222.5
# converged:                       True   LL-Null:                       -3774.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.3526      0.135    -24.914      0.000      -3.616      -3.089
# creation_source               -0.0740      0.044     -1.680      0.093      -0.160       0.012
# opted_in_to_mailing_list       0.1080      0.109      0.988      0.323      -0.106       0.322
# enabled_for_marketing_drip    -0.0493      0.135     -0.366      0.714      -0.313       0.215
# org_id                         0.0010      0.000      3.052      0.002       0.000       0.002
# active_days                    0.0114      0.000     39.577      0.000       0.011       0.012
# invited_by_user_id         -1.346e-05   1.45e-05     -0.926      0.354   -4.19e-05     1.5e-05
# ==============================================================================================
# """

# %%
print("==================Regression Coefficients are:========================'\n\n")
r=res_log.params[1:]
print(res_log.params[1:],'\n\n')
con_mat=res_log.pred_table()
con_mat
print("==================Accuracy on training data:========================'\n\n")
accuracy_train=100*(con_mat[0,0]+con_mat[1,1])/con_mat.sum()
print("Accuracy : ",accuracy_train)
# Out:
# ==================Regression Coefficients are:========================'
#
#
# creation_source              -0.073980
# opted_in_to_mailing_list      0.107977
# enabled_for_marketing_drip   -0.049296
# org_id                        0.001021
# active_days                   0.011440
# invited_by_user_id           -0.000013
# dtype: float64
#
#
# ==================Accuracy on training data:========================'
#
#
# Accuracy :  93.19166666666666

# %%
result=r.to_frame().reset_index()
a=list(result['index'])
b=list(result[0])

# %%
fig=plt.figure(figsize=(10,5),dpi=100)
plt.plot(a,b,marker='v')
plt.bar(a,b,width=0.2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# $\color{red}{\text{
# Results:}}$
#
# I used the algorithm Logistics Regression since the user is adopted (1) or not (0). The features are 'creation_source', 'opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'days_since_signup',active_days,invited_by_user_id.

# %% [markdown]
# $\color{blue}{\text{
# Accuracy score and regression coefficients are:}}$

# %%
print("==================Accuracy on training data:========================'\n\n")
print("Accuracy : ",accuracy_train,'\n\n')
print("==================Regression Coefficients are:========================'\n\n")
print(res_log.params[1:])
# Out:
# ==================Accuracy on training data:========================'
#
#
# Accuracy :  93.19166666666666
#
#
# ==================Regression Coefficients are:========================'
#
#
# creation_source              -0.073980
# opted_in_to_mailing_list      0.107977
# enabled_for_marketing_drip   -0.049296
# org_id                        0.001021
# active_days                   0.011440
# invited_by_user_id           -0.000013
# dtype: float64

# %% [markdown]
# $\color{red}{\text{
# Observation:}}$
#
# 1)-From the above plot its clear that Opting_into_mailing_list and and active days increase the odds of being adopted user
#
# 2)-Others like creation_source,org_id and invited by user only has slight impact in increasing the odds of adopted user.
#
# 3)-Only the enabling_for marketing_drip has odds of nat being an adopted user,

# %% [markdown]
# $\color{red}{\text{
# Further research/data:}}$

# %% [markdown]
# Further informations that helps to increase the odds of being the adopted user can be
#
# 1)-Gender that has more adopted user
#
# 2)-Age
#
# 3)-organisation that has more adopted user
#
# 4)-Particular field to which the user belong that attracts them to become an adopted user
#
# 5)-Location of the user
#
# 6)-salary details
